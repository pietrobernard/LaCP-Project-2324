# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, AveragePooling1D

# %% [markdown]
# ### Read data

# %%
def Show_data(x,L,s="data",T=3):
    c=("k","r","b")
    for i in range(T):
        j=i*3*L
        plt.plot(np.arange(j,j+L),x[i*3],c=c[0])
        plt.plot(np.arange(j+L,j+2*L),x[i*3+1],c=c[1])
        plt.plot(np.arange(j+2*L,j+3*L),x[i*3+2],c=c[2])
    plt.title(s)
    plt.xlabel("time")
    plt.show()
    
str0="ts_L80_N4000.dat"
fnamex='x_'+str0
fnamey='y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

Show_data(x,L,"part of the original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.
# Out:
# data:  4000

# %% [markdown]
# ### Rescale data, split train/val.

# %%
#
#  FIRST PASSAGE:  DO NOT DO THIS --> FAILURE 
#
# bring each sample to zero average
xm = x.mean(axis=1)
for i in range(N):
    x[i] = x[i]-xm[i]

#
#  SECOND PASSAGE:  DO NOT DO THIS --> ALSO FAILURE 
#
#rescale (crude version, variance should be used)
x = x / x.std()
    
Show_data(x,L,"rescaled data")

perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1)
# Out:
# N_train= 3200   N_val= 800   L= 80   n_class= 3

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

NCONV=2

def build_model(NCONV=1, NF=5,KS=6, NF2=5,KS2=4, lamb=0):
    """
    filter = kernel
    NCONV=index of the CNN architecture
    NF=nr of filters in the 1st layer
    KS=kernel size in the 1st layer
    NF2=nr of filters in the 2nd layer
    KS2=kernel size in the 2nd layer
    lamb=not the animal, but lambda, the regularization parameter
    """
    # regularizers, l2=Ridge, l1=LASSO
    reg = keras.regularizers.l2(lamb)
    model = Sequential()

    # Version with last layer Dense
    if NCONV==1:
        model.add(Conv1D(filters=5, 
                         kernel_size=KS,
                         kernel_regularizer=reg,
                         activation='relu', 
                         input_shape=input_shape))
        model.add(MaxPooling1D(3))
        #model.add(AveragePooling1D(3))
        model.add(Conv1D(filters=NF2, kernel_size=KS2,activation='relu'))
        model.add(Flatten())
        model.add(Dense(12, activation='relu'))
        model.add(Dropout(0.2))

    # Version with last layer GlobalMaxPooling, one more intermediate conv1D, and no intermediate pooling
    if NCONV==2:
        model.add(Conv1D(filters=NF, 
                         kernel_size=KS,
                         kernel_regularizer=reg,
                         activation='relu', 
                         input_shape=input_shape))
        model.add(Conv1D(filters=NF2, kernel_size=KS2,activation='relu'))
        model.add(Conv1D(filters=NF2, kernel_size=KS2,activation='relu'))
        model.add(tf.keras.layers.GlobalMaxPooling1D())
        model.add(Flatten())
        
    # Last layer, with n_class units  
    model.add(Dense(n_class, activation='softmax')) # softmax !
    
    # optimizers
    # .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
    # .RMSprop()
    # .Nadam()
    # Define the optimizer learning rate as a hyperparameter.
    opt = keras.optimizers.Adam()
    
    # compile the model
    # categorical_crossentropy, 3 output nodes
    model.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])
    return model

model=build_model(NCONV=NCONV,KS=11)


print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.SGD(learning_rate=10**-1, momentum=0.9, nesterov=True)

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])

print(model.layers)
# Out:
# ----- Model 2 -----
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_45 (Conv1D)          (None, 70, 5)             60
#
#  conv1d_46 (Conv1D)          (None, 67, 5)             105
#
#  conv1d_47 (Conv1D)          (None, 64, 5)             105
#
#  global_max_pooling1d_15 (Gl  (None, 5)                0
#  obalMaxPooling1D)
#
#  flatten_15 (Flatten)        (None, 5)                 0
#
#  dense_15 (Dense)            (None, 3)                 18
#
# =================================================================
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# _________________________________________________________________
# None
# [<keras.layers.convolutional.conv1d.Conv1D object at 0x00000138A77AFBB0>, <keras.layers.convolutional.conv1d.Conv1D object at 0x00000138A34FFF40>, <keras.layers.convolutional.conv1d.Conv1D object at 0x00000138AE303F70>, <keras.layers.pooling.global_max_pooling1d.GlobalMaxPooling1D object at 0x00000138A7767FA0>, <keras.layers.reshaping.flatten.Flatten object at 0x00000138AE1B5760>, <keras.layers.core.dense.Dense object at 0x00000138AE1CCB50>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m','k',"gray","cyan","g"]
    m=['o','s','D','<','>','^','+','x','d',"*"]
    ms=10
    
    w = model.layers[l].get_weights()[0]
    wT=w.T
    M=len(wT)
    b = model.layers[l].get_weights()[1]
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i%len(c)],marker=m[i%len(m)],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i%len(c)],marker=m[i%len(m)],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 200
EPOCHS = 300

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True) 
print("end of fit")
# Out:
# ----- Model  2 -----
# FITTING....
# Epoch 1/300
# 16/16 - 2s - loss: 1.1146 - accuracy: 0.3572 - val_loss: 1.0897 - val_accuracy: 0.3900 - 2s/epoch - 95ms/step
# Epoch 2/300
# 16/16 - 1s - loss: 1.0744 - accuracy: 0.4259 - val_loss: 1.0455 - val_accuracy: 0.4638 - 1s/epoch - 73ms/step
# Epoch 3/300
# 16/16 - 1s - loss: 1.0082 - accuracy: 0.4969 - val_loss: 0.9993 - val_accuracy: 0.4975 - 770ms/epoch - 48ms/step
# Epoch 4/300
# 16/16 - 1s - loss: 0.9406 - accuracy: 0.5522 - val_loss: 0.9113 - val_accuracy: 0.5587 - 967ms/epoch - 60ms/step
# Epoch 5/300
# 16/16 - 1s - loss: 0.9374 - accuracy: 0.5462 - val_loss: 0.9128 - val_accuracy: 0.5850 - 781ms/epoch - 49ms/step
# Epoch 6/300
# 16/16 - 1s - loss: 0.8913 - accuracy: 0.5753 - val_loss: 0.8591 - val_accuracy: 0.6225 - 691ms/epoch - 43ms/step
# Epoch 7/300
# 16/16 - 1s - loss: 0.8761 - accuracy: 0.5847 - val_loss: 0.8349 - val_accuracy: 0.6212 - 944ms/epoch - 59ms/step
# Epoch 8/300
# 16/16 - 1s - loss: 0.8967 - accuracy: 0.5825 - val_loss: 0.8110 - val_accuracy: 0.6325 - 952ms/epoch - 60ms/step
# Epoch 9/300
# 16/16 - 1s - loss: 0.8435 - accuracy: 0.6125 - val_loss: 0.7783 - val_accuracy: 0.6488 - 959ms/epoch - 60ms/step
# Epoch 10/300
# 16/16 - 1s - loss: 0.8212 - accuracy: 0.6359 - val_loss: 0.7659 - val_accuracy: 0.6675 - 909ms/epoch - 57ms/step
# Epoch 11/300
# 16/16 - 1s - loss: 0.7405 - accuracy: 0.6837 - val_loss: 0.7554 - val_accuracy: 0.6600 - 855ms/epoch - 53ms/step
# Epoch 12/300
# 16/16 - 1s - loss: 0.6996 - accuracy: 0.7116 - val_loss: 0.6586 - val_accuracy: 0.7350 - 869ms/epoch - 54ms/step
# Epoch 13/300
# 16/16 - 1s - loss: 0.7210 - accuracy: 0.7013 - val_loss: 0.6498 - val_accuracy: 0.7425 - 810ms/epoch - 51ms/step
# Epoch 14/300
# 16/16 - 1s - loss: 0.6767 - accuracy: 0.7219 - val_loss: 0.6524 - val_accuracy: 0.7437 - 706ms/epoch - 44ms/step
# Epoch 15/300
# 16/16 - 1s - loss: 0.6536 - accuracy: 0.7397 - val_loss: 0.6401 - val_accuracy: 0.7387 - 691ms/epoch - 43ms/step
# Epoch 16/300
# 16/16 - 1s - loss: 0.6504 - accuracy: 0.7328 - val_loss: 0.6135 - val_accuracy: 0.7625 - 693ms/epoch - 43ms/step
# Epoch 17/300
# 16/16 - 1s - loss: 0.6475 - accuracy: 0.7291 - val_loss: 0.6400 - val_accuracy: 0.7362 - 695ms/epoch - 43ms/step
# Epoch 18/300
# 16/16 - 1s - loss: 0.6682 - accuracy: 0.7256 - val_loss: 0.6486 - val_accuracy: 0.7362 - 739ms/epoch - 46ms/step
# Epoch 19/300
# 16/16 - 1s - loss: 0.6514 - accuracy: 0.7281 - val_loss: 0.7651 - val_accuracy: 0.6812 - 983ms/epoch - 61ms/step
# Epoch 20/300
# 16/16 - 1s - loss: 0.6507 - accuracy: 0.7300 - val_loss: 0.8312 - val_accuracy: 0.6587 - 925ms/epoch - 58ms/step
# Epoch 21/300
# 16/16 - 1s - loss: 0.6596 - accuracy: 0.7266 - val_loss: 0.6135 - val_accuracy: 0.7600 - 986ms/epoch - 62ms/step
# Epoch 22/300
# 16/16 - 1s - loss: 0.6481 - accuracy: 0.7319 - val_loss: 0.6216 - val_accuracy: 0.7550 - 789ms/epoch - 49ms/step
# Epoch 23/300
# 16/16 - 1s - loss: 0.6474 - accuracy: 0.7381 - val_loss: 0.6316 - val_accuracy: 0.7500 - 880ms/epoch - 55ms/step
# Epoch 24/300
# 16/16 - 1s - loss: 0.6298 - accuracy: 0.7453 - val_loss: 0.6349 - val_accuracy: 0.7462 - 742ms/epoch - 46ms/step
# Epoch 25/300
# 16/16 - 1s - loss: 0.6545 - accuracy: 0.7294 - val_loss: 0.6301 - val_accuracy: 0.7525 - 903ms/epoch - 56ms/step
# Epoch 26/300
# 16/16 - 1s - loss: 0.6272 - accuracy: 0.7469 - val_loss: 0.6457 - val_accuracy: 0.7362 - 1s/epoch - 69ms/step
# Epoch 27/300
# 16/16 - 1s - loss: 0.6424 - accuracy: 0.7422 - val_loss: 0.6274 - val_accuracy: 0.7450 - 843ms/epoch - 53ms/step
# Epoch 28/300
# 16/16 - 1s - loss: 0.6294 - accuracy: 0.7381 - val_loss: 0.6075 - val_accuracy: 0.7700 - 932ms/epoch - 58ms/step
# Epoch 29/300
# 16/16 - 1s - loss: 0.6351 - accuracy: 0.7391 - val_loss: 0.6275 - val_accuracy: 0.7588 - 884ms/epoch - 55ms/step
# Epoch 30/300
# 16/16 - 1s - loss: 0.6373 - accuracy: 0.7422 - val_loss: 0.6449 - val_accuracy: 0.7500 - 864ms/epoch - 54ms/step
# Epoch 31/300
# 16/16 - 1s - loss: 0.6310 - accuracy: 0.7450 - val_loss: 0.6592 - val_accuracy: 0.7312 - 897ms/epoch - 56ms/step
# Epoch 32/300
# 16/16 - 1s - loss: 0.6241 - accuracy: 0.7487 - val_loss: 0.5970 - val_accuracy: 0.7725 - 892ms/epoch - 56ms/step
# Epoch 33/300
# 16/16 - 1s - loss: 0.6289 - accuracy: 0.7447 - val_loss: 0.6834 - val_accuracy: 0.7250 - 1s/epoch - 64ms/step
# Epoch 34/300
# 16/16 - 1s - loss: 0.6266 - accuracy: 0.7419 - val_loss: 0.6115 - val_accuracy: 0.7700 - 923ms/epoch - 58ms/step
# Epoch 35/300
# 16/16 - 1s - loss: 0.6262 - accuracy: 0.7416 - val_loss: 0.6923 - val_accuracy: 0.7337 - 870ms/epoch - 54ms/step
# Epoch 36/300
# 16/16 - 1s - loss: 0.6378 - accuracy: 0.7387 - val_loss: 0.6433 - val_accuracy: 0.7563 - 1s/epoch - 67ms/step
# Epoch 37/300
# 16/16 - 1s - loss: 0.6251 - accuracy: 0.7419 - val_loss: 0.5998 - val_accuracy: 0.7650 - 831ms/epoch - 52ms/step
# Epoch 38/300
# 16/16 - 1s - loss: 0.6258 - accuracy: 0.7469 - val_loss: 0.6651 - val_accuracy: 0.7425 - 943ms/epoch - 59ms/step
# Epoch 39/300
# 16/16 - 1s - loss: 0.6311 - accuracy: 0.7384 - val_loss: 0.6007 - val_accuracy: 0.7700 - 849ms/epoch - 53ms/step
# Epoch 40/300
# 16/16 - 1s - loss: 0.6122 - accuracy: 0.7481 - val_loss: 0.6046 - val_accuracy: 0.7713 - 918ms/epoch - 57ms/step
# Epoch 41/300
# 16/16 - 1s - loss: 0.6260 - accuracy: 0.7441 - val_loss: 0.6132 - val_accuracy: 0.7663 - 844ms/epoch - 53ms/step
# Epoch 42/300
# 16/16 - 1s - loss: 0.6135 - accuracy: 0.7509 - val_loss: 0.6567 - val_accuracy: 0.7462 - 930ms/epoch - 58ms/step
# Epoch 43/300
# 16/16 - 1s - loss: 0.6632 - accuracy: 0.7269 - val_loss: 0.6338 - val_accuracy: 0.7425 - 1s/epoch - 72ms/step
# Epoch 44/300
# 16/16 - 1s - loss: 0.6350 - accuracy: 0.7462 - val_loss: 0.6955 - val_accuracy: 0.7312 - 906ms/epoch - 57ms/step
# Epoch 45/300
# 16/16 - 1s - loss: 0.6129 - accuracy: 0.7525 - val_loss: 0.6071 - val_accuracy: 0.7613 - 973ms/epoch - 61ms/step
# Epoch 46/300
# 16/16 - 1s - loss: 0.6093 - accuracy: 0.7434 - val_loss: 0.5935 - val_accuracy: 0.7750 - 807ms/epoch - 50ms/step
# Epoch 47/300
# 16/16 - 1s - loss: 0.6830 - accuracy: 0.7150 - val_loss: 0.5991 - val_accuracy: 0.7625 - 1s/epoch - 67ms/step
# Epoch 48/300
# 16/16 - 1s - loss: 0.6223 - accuracy: 0.7475 - val_loss: 0.6306 - val_accuracy: 0.7675 - 997ms/epoch - 62ms/step
# Epoch 49/300
# 16/16 - 1s - loss: 0.6226 - accuracy: 0.7406 - val_loss: 0.6295 - val_accuracy: 0.7525 - 737ms/epoch - 46ms/step
# Epoch 50/300
# 16/16 - 1s - loss: 0.6146 - accuracy: 0.7447 - val_loss: 0.5950 - val_accuracy: 0.7613 - 738ms/epoch - 46ms/step
# Epoch 51/300
# 16/16 - 1s - loss: 0.6277 - accuracy: 0.7425 - val_loss: 0.6098 - val_accuracy: 0.7638 - 811ms/epoch - 51ms/step
# Epoch 52/300
# 16/16 - 1s - loss: 0.6048 - accuracy: 0.7484 - val_loss: 0.5824 - val_accuracy: 0.7750 - 800ms/epoch - 50ms/step
# Epoch 53/300
# 16/16 - 1s - loss: 0.6237 - accuracy: 0.7391 - val_loss: 0.6292 - val_accuracy: 0.7437 - 839ms/epoch - 52ms/step
# Epoch 54/300
# 16/16 - 1s - loss: 0.6239 - accuracy: 0.7434 - val_loss: 0.6740 - val_accuracy: 0.7300 - 993ms/epoch - 62ms/step
# Epoch 55/300
# 16/16 - 1s - loss: 0.6245 - accuracy: 0.7412 - val_loss: 0.5846 - val_accuracy: 0.7713 - 801ms/epoch - 50ms/step
# Epoch 56/300
# 16/16 - 1s - loss: 0.6194 - accuracy: 0.7425 - val_loss: 0.5903 - val_accuracy: 0.7688 - 1s/epoch - 72ms/step
# Epoch 57/300
# 16/16 - 1s - loss: 0.6102 - accuracy: 0.7513 - val_loss: 0.5938 - val_accuracy: 0.7775 - 1s/epoch - 75ms/step
# Epoch 58/300
# 16/16 - 1s - loss: 0.6063 - accuracy: 0.7450 - val_loss: 0.5973 - val_accuracy: 0.7725 - 919ms/epoch - 57ms/step
# Epoch 59/300
# 16/16 - 1s - loss: 0.6178 - accuracy: 0.7450 - val_loss: 0.6024 - val_accuracy: 0.7650 - 786ms/epoch - 49ms/step
# Epoch 60/300
# 16/16 - 1s - loss: 0.6273 - accuracy: 0.7394 - val_loss: 0.6164 - val_accuracy: 0.7563 - 977ms/epoch - 61ms/step
# Epoch 61/300
# 16/16 - 1s - loss: 0.6157 - accuracy: 0.7466 - val_loss: 0.5780 - val_accuracy: 0.7763 - 871ms/epoch - 54ms/step
# Epoch 62/300
# 16/16 - 1s - loss: 0.6090 - accuracy: 0.7491 - val_loss: 0.6141 - val_accuracy: 0.7563 - 882ms/epoch - 55ms/step
# Epoch 63/300
# 16/16 - 1s - loss: 0.6218 - accuracy: 0.7428 - val_loss: 0.5959 - val_accuracy: 0.7738 - 1s/epoch - 65ms/step
# Epoch 64/300
# 16/16 - 1s - loss: 0.6181 - accuracy: 0.7441 - val_loss: 0.6167 - val_accuracy: 0.7625 - 815ms/epoch - 51ms/step
# Epoch 65/300
# 16/16 - 1s - loss: 0.6108 - accuracy: 0.7556 - val_loss: 0.5855 - val_accuracy: 0.7663 - 1s/epoch - 72ms/step
# Epoch 66/300
# 16/16 - 1s - loss: 0.6181 - accuracy: 0.7453 - val_loss: 0.6266 - val_accuracy: 0.7613 - 881ms/epoch - 55ms/step
# Epoch 67/300
# 16/16 - 1s - loss: 0.6054 - accuracy: 0.7578 - val_loss: 0.6033 - val_accuracy: 0.7638 - 1s/epoch - 76ms/step
# Epoch 68/300
# 16/16 - 1s - loss: 0.6584 - accuracy: 0.7278 - val_loss: 0.6154 - val_accuracy: 0.7663 - 1s/epoch - 65ms/step
# Epoch 69/300
# 16/16 - 1s - loss: 0.6216 - accuracy: 0.7419 - val_loss: 0.5954 - val_accuracy: 0.7738 - 870ms/epoch - 54ms/step
# Epoch 70/300
# 16/16 - 1s - loss: 0.6078 - accuracy: 0.7441 - val_loss: 0.6619 - val_accuracy: 0.7300 - 925ms/epoch - 58ms/step
# Epoch 71/300
# 16/16 - 1s - loss: 0.6299 - accuracy: 0.7378 - val_loss: 0.5727 - val_accuracy: 0.7713 - 915ms/epoch - 57ms/step
# Epoch 72/300
# 16/16 - 1s - loss: 0.6213 - accuracy: 0.7487 - val_loss: 0.5974 - val_accuracy: 0.7725 - 869ms/epoch - 54ms/step
# Epoch 73/300
# 16/16 - 1s - loss: 0.5971 - accuracy: 0.7541 - val_loss: 0.5932 - val_accuracy: 0.7675 - 743ms/epoch - 46ms/step
# Epoch 74/300
# 16/16 - 1s - loss: 0.6160 - accuracy: 0.7475 - val_loss: 0.5974 - val_accuracy: 0.7650 - 917ms/epoch - 57ms/step
# Epoch 75/300
# 16/16 - 1s - loss: 0.6144 - accuracy: 0.7528 - val_loss: 0.5854 - val_accuracy: 0.7788 - 849ms/epoch - 53ms/step
# Epoch 76/300
# 16/16 - 1s - loss: 0.6323 - accuracy: 0.7484 - val_loss: 0.6118 - val_accuracy: 0.7600 - 822ms/epoch - 51ms/step
# Epoch 77/300
# 16/16 - 1s - loss: 0.6266 - accuracy: 0.7444 - val_loss: 0.5887 - val_accuracy: 0.7850 - 1s/epoch - 67ms/step
# Epoch 78/300
# 16/16 - 1s - loss: 0.6010 - accuracy: 0.7559 - val_loss: 0.6028 - val_accuracy: 0.7550 - 923ms/epoch - 58ms/step
# Epoch 79/300
# 16/16 - 1s - loss: 0.6381 - accuracy: 0.7375 - val_loss: 0.6453 - val_accuracy: 0.7425 - 825ms/epoch - 52ms/step
# Epoch 80/300
# 16/16 - 1s - loss: 0.5993 - accuracy: 0.7534 - val_loss: 0.6013 - val_accuracy: 0.7650 - 953ms/epoch - 60ms/step
# Epoch 81/300
# 16/16 - 1s - loss: 0.6121 - accuracy: 0.7484 - val_loss: 0.5942 - val_accuracy: 0.7550 - 901ms/epoch - 56ms/step
# Epoch 82/300
# 16/16 - 1s - loss: 0.6080 - accuracy: 0.7572 - val_loss: 0.6067 - val_accuracy: 0.7700 - 749ms/epoch - 47ms/step
# Epoch 83/300
# 16/16 - 1s - loss: 0.5983 - accuracy: 0.7569 - val_loss: 0.6512 - val_accuracy: 0.7400 - 720ms/epoch - 45ms/step
# Epoch 84/300
# 16/16 - 1s - loss: 0.6046 - accuracy: 0.7584 - val_loss: 0.6248 - val_accuracy: 0.7575 - 872ms/epoch - 54ms/step
# Epoch 85/300
# 16/16 - 1s - loss: 0.6397 - accuracy: 0.7381 - val_loss: 0.5796 - val_accuracy: 0.7725 - 980ms/epoch - 61ms/step
# Epoch 86/300
# 16/16 - 1s - loss: 0.6009 - accuracy: 0.7547 - val_loss: 0.6440 - val_accuracy: 0.7375 - 1s/epoch - 63ms/step
# Epoch 87/300
# 16/16 - 1s - loss: 0.6022 - accuracy: 0.7513 - val_loss: 0.6289 - val_accuracy: 0.7538 - 846ms/epoch - 53ms/step
# Epoch 88/300
# 16/16 - 1s - loss: 0.5966 - accuracy: 0.7563 - val_loss: 0.5933 - val_accuracy: 0.7663 - 1s/epoch - 63ms/step
# Epoch 89/300
# 16/16 - 1s - loss: 0.6395 - accuracy: 0.7287 - val_loss: 0.5978 - val_accuracy: 0.7700 - 986ms/epoch - 62ms/step
# Epoch 90/300
# 16/16 - 1s - loss: 0.6101 - accuracy: 0.7538 - val_loss: 0.6378 - val_accuracy: 0.7650 - 1s/epoch - 70ms/step
# Epoch 91/300
# 16/16 - 1s - loss: 0.5961 - accuracy: 0.7503 - val_loss: 0.5816 - val_accuracy: 0.7775 - 1s/epoch - 68ms/step
# Epoch 92/300
# 16/16 - 1s - loss: 0.6144 - accuracy: 0.7487 - val_loss: 0.5838 - val_accuracy: 0.7650 - 971ms/epoch - 61ms/step
# Epoch 93/300
# 16/16 - 1s - loss: 0.6018 - accuracy: 0.7513 - val_loss: 0.5662 - val_accuracy: 0.7850 - 885ms/epoch - 55ms/step
# Epoch 94/300
# 16/16 - 1s - loss: 0.6131 - accuracy: 0.7491 - val_loss: 0.6269 - val_accuracy: 0.7500 - 928ms/epoch - 58ms/step
# Epoch 95/300
# 16/16 - 1s - loss: 0.6046 - accuracy: 0.7550 - val_loss: 0.5847 - val_accuracy: 0.7675 - 883ms/epoch - 55ms/step
# Epoch 96/300
# 16/16 - 1s - loss: 0.5938 - accuracy: 0.7497 - val_loss: 0.6928 - val_accuracy: 0.7387 - 959ms/epoch - 60ms/step
# Epoch 97/300
# 16/16 - 1s - loss: 0.6162 - accuracy: 0.7456 - val_loss: 0.5714 - val_accuracy: 0.7825 - 838ms/epoch - 52ms/step
# Epoch 98/300
# 16/16 - 1s - loss: 0.6142 - accuracy: 0.7478 - val_loss: 0.6322 - val_accuracy: 0.7713 - 1s/epoch - 66ms/step
# Epoch 99/300
# 16/16 - 1s - loss: 0.6174 - accuracy: 0.7513 - val_loss: 0.5801 - val_accuracy: 0.7700 - 992ms/epoch - 62ms/step
# Epoch 100/300
# 16/16 - 1s - loss: 0.6072 - accuracy: 0.7522 - val_loss: 0.6100 - val_accuracy: 0.7600 - 749ms/epoch - 47ms/step
# Epoch 101/300
# 16/16 - 1s - loss: 0.6047 - accuracy: 0.7534 - val_loss: 0.5909 - val_accuracy: 0.7663 - 910ms/epoch - 57ms/step
# Epoch 102/300
# 16/16 - 1s - loss: 0.6019 - accuracy: 0.7553 - val_loss: 0.6108 - val_accuracy: 0.7575 - 1s/epoch - 70ms/step
# Epoch 103/300
# 16/16 - 1s - loss: 0.5983 - accuracy: 0.7569 - val_loss: 0.6016 - val_accuracy: 0.7563 - 700ms/epoch - 44ms/step
# Epoch 104/300
# 16/16 - 1s - loss: 0.5920 - accuracy: 0.7578 - val_loss: 0.5811 - val_accuracy: 0.7688 - 760ms/epoch - 47ms/step
# Epoch 105/300
# 16/16 - 1s - loss: 0.5942 - accuracy: 0.7538 - val_loss: 0.5973 - val_accuracy: 0.7538 - 796ms/epoch - 50ms/step
# Epoch 106/300
# 16/16 - 1s - loss: 0.6140 - accuracy: 0.7531 - val_loss: 0.5906 - val_accuracy: 0.7625 - 745ms/epoch - 47ms/step
# Epoch 107/300
# 16/16 - 1s - loss: 0.6230 - accuracy: 0.7412 - val_loss: 0.5958 - val_accuracy: 0.7812 - 761ms/epoch - 48ms/step
# Epoch 108/300
# 16/16 - 1s - loss: 0.6036 - accuracy: 0.7528 - val_loss: 0.6443 - val_accuracy: 0.7575 - 934ms/epoch - 58ms/step
# Epoch 109/300
# 16/16 - 1s - loss: 0.6099 - accuracy: 0.7528 - val_loss: 0.5888 - val_accuracy: 0.7688 - 849ms/epoch - 53ms/step
# Epoch 110/300
# 16/16 - 1s - loss: 0.6027 - accuracy: 0.7513 - val_loss: 0.6046 - val_accuracy: 0.7487 - 893ms/epoch - 56ms/step
# Epoch 111/300
# 16/16 - 1s - loss: 0.6027 - accuracy: 0.7550 - val_loss: 0.5829 - val_accuracy: 0.7588 - 777ms/epoch - 49ms/step
# Epoch 112/300
# 16/16 - 1s - loss: 0.5863 - accuracy: 0.7594 - val_loss: 0.6210 - val_accuracy: 0.7513 - 837ms/epoch - 52ms/step
# Epoch 113/300
# 16/16 - 1s - loss: 0.5978 - accuracy: 0.7584 - val_loss: 0.6132 - val_accuracy: 0.7788 - 778ms/epoch - 49ms/step
# Epoch 114/300
# 16/16 - 1s - loss: 0.5889 - accuracy: 0.7609 - val_loss: 0.6048 - val_accuracy: 0.7650 - 769ms/epoch - 48ms/step
# Epoch 115/300
# 16/16 - 1s - loss: 0.6088 - accuracy: 0.7556 - val_loss: 0.5795 - val_accuracy: 0.7725 - 779ms/epoch - 49ms/step
# Epoch 116/300
# 16/16 - 1s - loss: 0.5898 - accuracy: 0.7594 - val_loss: 0.6282 - val_accuracy: 0.7513 - 691ms/epoch - 43ms/step
# Epoch 117/300
# 16/16 - 1s - loss: 0.5813 - accuracy: 0.7672 - val_loss: 0.6086 - val_accuracy: 0.7663 - 780ms/epoch - 49ms/step
# Epoch 118/300
# 16/16 - 1s - loss: 0.6237 - accuracy: 0.7487 - val_loss: 0.5789 - val_accuracy: 0.7837 - 686ms/epoch - 43ms/step
# Epoch 119/300
# 16/16 - 1s - loss: 0.5848 - accuracy: 0.7572 - val_loss: 0.5657 - val_accuracy: 0.7837 - 814ms/epoch - 51ms/step
# Epoch 120/300
# 16/16 - 1s - loss: 0.5979 - accuracy: 0.7494 - val_loss: 0.5725 - val_accuracy: 0.7812 - 683ms/epoch - 43ms/step
# Epoch 121/300
# 16/16 - 1s - loss: 0.5975 - accuracy: 0.7606 - val_loss: 0.6420 - val_accuracy: 0.7525 - 692ms/epoch - 43ms/step
# Epoch 122/300
# 16/16 - 1s - loss: 0.6070 - accuracy: 0.7487 - val_loss: 0.5806 - val_accuracy: 0.7725 - 731ms/epoch - 46ms/step
# Epoch 123/300
# 16/16 - 1s - loss: 0.5802 - accuracy: 0.7641 - val_loss: 0.6393 - val_accuracy: 0.7588 - 899ms/epoch - 56ms/step
# Epoch 124/300
# 16/16 - 1s - loss: 0.5899 - accuracy: 0.7638 - val_loss: 0.5765 - val_accuracy: 0.7700 - 791ms/epoch - 49ms/step
# Epoch 125/300
# 16/16 - 1s - loss: 0.6152 - accuracy: 0.7491 - val_loss: 0.6425 - val_accuracy: 0.7550 - 767ms/epoch - 48ms/step
# Epoch 126/300
# 16/16 - 1s - loss: 0.6057 - accuracy: 0.7462 - val_loss: 0.5932 - val_accuracy: 0.7675 - 811ms/epoch - 51ms/step
# Epoch 127/300
# 16/16 - 1s - loss: 0.6206 - accuracy: 0.7453 - val_loss: 0.5813 - val_accuracy: 0.7763 - 778ms/epoch - 49ms/step
# Epoch 128/300
# 16/16 - 1s - loss: 0.6204 - accuracy: 0.7428 - val_loss: 0.5912 - val_accuracy: 0.7725 - 939ms/epoch - 59ms/step
# Epoch 129/300
# 16/16 - 1s - loss: 0.6183 - accuracy: 0.7419 - val_loss: 0.5732 - val_accuracy: 0.7800 - 722ms/epoch - 45ms/step
# Epoch 130/300
# 16/16 - 1s - loss: 0.5878 - accuracy: 0.7594 - val_loss: 0.6723 - val_accuracy: 0.7450 - 910ms/epoch - 57ms/step
# Epoch 131/300
# 16/16 - 1s - loss: 0.5937 - accuracy: 0.7606 - val_loss: 0.6108 - val_accuracy: 0.7538 - 895ms/epoch - 56ms/step
# Epoch 132/300
# 16/16 - 1s - loss: 0.5882 - accuracy: 0.7603 - val_loss: 0.5730 - val_accuracy: 0.7812 - 908ms/epoch - 57ms/step
# Epoch 133/300
# 16/16 - 1s - loss: 0.5973 - accuracy: 0.7541 - val_loss: 0.6493 - val_accuracy: 0.7550 - 889ms/epoch - 56ms/step
# Epoch 134/300
# 16/16 - 1s - loss: 0.6092 - accuracy: 0.7509 - val_loss: 0.5970 - val_accuracy: 0.7750 - 744ms/epoch - 47ms/step
# Epoch 135/300
# 16/16 - 1s - loss: 0.5966 - accuracy: 0.7538 - val_loss: 0.6719 - val_accuracy: 0.7425 - 1s/epoch - 64ms/step
# Epoch 136/300
# 16/16 - 1s - loss: 0.5994 - accuracy: 0.7484 - val_loss: 0.5691 - val_accuracy: 0.7738 - 801ms/epoch - 50ms/step
# Epoch 137/300
# 16/16 - 1s - loss: 0.5968 - accuracy: 0.7581 - val_loss: 0.6093 - val_accuracy: 0.7538 - 978ms/epoch - 61ms/step
# Epoch 138/300
# 16/16 - 1s - loss: 0.5816 - accuracy: 0.7597 - val_loss: 0.6669 - val_accuracy: 0.7387 - 972ms/epoch - 61ms/step
# Epoch 139/300
# 16/16 - 1s - loss: 0.6071 - accuracy: 0.7491 - val_loss: 0.6341 - val_accuracy: 0.7575 - 848ms/epoch - 53ms/step
# Epoch 140/300
# 16/16 - 1s - loss: 0.5911 - accuracy: 0.7578 - val_loss: 0.5890 - val_accuracy: 0.7663 - 935ms/epoch - 58ms/step
# Epoch 141/300
# 16/16 - 1s - loss: 0.5987 - accuracy: 0.7544 - val_loss: 0.5751 - val_accuracy: 0.7750 - 785ms/epoch - 49ms/step
# Epoch 142/300
# 16/16 - 1s - loss: 0.6072 - accuracy: 0.7522 - val_loss: 0.6393 - val_accuracy: 0.7588 - 901ms/epoch - 56ms/step
# Epoch 143/300
# 16/16 - 1s - loss: 0.5962 - accuracy: 0.7559 - val_loss: 0.5799 - val_accuracy: 0.7800 - 664ms/epoch - 41ms/step
# Epoch 144/300
# 16/16 - 1s - loss: 0.5980 - accuracy: 0.7534 - val_loss: 0.6030 - val_accuracy: 0.7638 - 702ms/epoch - 44ms/step
# Epoch 145/300
# 16/16 - 1s - loss: 0.5809 - accuracy: 0.7650 - val_loss: 0.6221 - val_accuracy: 0.7738 - 684ms/epoch - 43ms/step
# Epoch 146/300
# 16/16 - 1s - loss: 0.5748 - accuracy: 0.7584 - val_loss: 0.5854 - val_accuracy: 0.7725 - 697ms/epoch - 44ms/step
# Epoch 147/300
# 16/16 - 1s - loss: 0.5847 - accuracy: 0.7609 - val_loss: 0.5967 - val_accuracy: 0.7675 - 879ms/epoch - 55ms/step
# Epoch 148/300
# 16/16 - 1s - loss: 0.6110 - accuracy: 0.7437 - val_loss: 0.6406 - val_accuracy: 0.7500 - 729ms/epoch - 46ms/step
# Epoch 149/300
# 16/16 - 1s - loss: 0.5880 - accuracy: 0.7556 - val_loss: 0.5970 - val_accuracy: 0.7775 - 972ms/epoch - 61ms/step
# Epoch 150/300
# 16/16 - 1s - loss: 0.5859 - accuracy: 0.7597 - val_loss: 0.6049 - val_accuracy: 0.7738 - 1s/epoch - 70ms/step
# Epoch 151/300
# 16/16 - 1s - loss: 0.5779 - accuracy: 0.7650 - val_loss: 0.5839 - val_accuracy: 0.7750 - 840ms/epoch - 52ms/step
# Epoch 152/300
# 16/16 - 1s - loss: 0.5743 - accuracy: 0.7650 - val_loss: 0.5967 - val_accuracy: 0.7663 - 857ms/epoch - 54ms/step
# Epoch 153/300
# 16/16 - 1s - loss: 0.5746 - accuracy: 0.7606 - val_loss: 0.5833 - val_accuracy: 0.7725 - 754ms/epoch - 47ms/step
# Epoch 154/300
# 16/16 - 1s - loss: 0.6429 - accuracy: 0.7434 - val_loss: 0.5906 - val_accuracy: 0.7837 - 865ms/epoch - 54ms/step
# Epoch 155/300
# 16/16 - 1s - loss: 0.5981 - accuracy: 0.7597 - val_loss: 0.5728 - val_accuracy: 0.7775 - 844ms/epoch - 53ms/step
# Epoch 156/300
# 16/16 - 1s - loss: 0.5874 - accuracy: 0.7609 - val_loss: 0.6012 - val_accuracy: 0.7725 - 825ms/epoch - 52ms/step
# Epoch 157/300
# 16/16 - 1s - loss: 0.5807 - accuracy: 0.7634 - val_loss: 0.5915 - val_accuracy: 0.7788 - 1s/epoch - 65ms/step
# Epoch 158/300
# 16/16 - 1s - loss: 0.5740 - accuracy: 0.7647 - val_loss: 0.5602 - val_accuracy: 0.7837 - 796ms/epoch - 50ms/step
# Epoch 159/300
# 16/16 - 1s - loss: 0.6029 - accuracy: 0.7566 - val_loss: 0.6004 - val_accuracy: 0.7763 - 694ms/epoch - 43ms/step
# Epoch 160/300
# 16/16 - 1s - loss: 0.5654 - accuracy: 0.7669 - val_loss: 0.6116 - val_accuracy: 0.7588 - 1s/epoch - 76ms/step
# Epoch 161/300
# 16/16 - 1s - loss: 0.5893 - accuracy: 0.7544 - val_loss: 0.6685 - val_accuracy: 0.7462 - 1s/epoch - 63ms/step
# Epoch 162/300
# 16/16 - 1s - loss: 0.5980 - accuracy: 0.7544 - val_loss: 0.6427 - val_accuracy: 0.7425 - 863ms/epoch - 54ms/step
# Epoch 163/300
# 16/16 - 1s - loss: 0.6013 - accuracy: 0.7531 - val_loss: 0.5947 - val_accuracy: 0.7775 - 1s/epoch - 67ms/step
# Epoch 164/300
# 16/16 - 1s - loss: 0.5717 - accuracy: 0.7675 - val_loss: 0.6093 - val_accuracy: 0.7775 - 710ms/epoch - 44ms/step
# Epoch 165/300
# 16/16 - 1s - loss: 0.5688 - accuracy: 0.7675 - val_loss: 0.5815 - val_accuracy: 0.7837 - 760ms/epoch - 47ms/step
# Epoch 166/300
# 16/16 - 1s - loss: 0.5687 - accuracy: 0.7688 - val_loss: 0.6453 - val_accuracy: 0.7638 - 719ms/epoch - 45ms/step
# Epoch 167/300
# 16/16 - 1s - loss: 0.5757 - accuracy: 0.7616 - val_loss: 0.7161 - val_accuracy: 0.7150 - 848ms/epoch - 53ms/step
# Epoch 168/300
# 16/16 - 1s - loss: 0.6000 - accuracy: 0.7503 - val_loss: 0.5931 - val_accuracy: 0.7788 - 804ms/epoch - 50ms/step
# Epoch 169/300
# 16/16 - 1s - loss: 0.5735 - accuracy: 0.7641 - val_loss: 0.5846 - val_accuracy: 0.7862 - 883ms/epoch - 55ms/step
# Epoch 170/300
# 16/16 - 1s - loss: 0.5752 - accuracy: 0.7700 - val_loss: 0.5881 - val_accuracy: 0.7825 - 761ms/epoch - 48ms/step
# Epoch 171/300
# 16/16 - 1s - loss: 0.5985 - accuracy: 0.7597 - val_loss: 0.6073 - val_accuracy: 0.7700 - 808ms/epoch - 50ms/step
# Epoch 172/300
# 16/16 - 1s - loss: 0.5783 - accuracy: 0.7675 - val_loss: 0.5877 - val_accuracy: 0.7700 - 1s/epoch - 63ms/step
# Epoch 173/300
# 16/16 - 1s - loss: 0.5953 - accuracy: 0.7534 - val_loss: 0.6171 - val_accuracy: 0.7638 - 890ms/epoch - 56ms/step
# Epoch 174/300
# 16/16 - 1s - loss: 0.5765 - accuracy: 0.7669 - val_loss: 0.6099 - val_accuracy: 0.7700 - 750ms/epoch - 47ms/step
# Epoch 175/300
# 16/16 - 1s - loss: 0.5733 - accuracy: 0.7638 - val_loss: 0.5845 - val_accuracy: 0.7800 - 783ms/epoch - 49ms/step
# Epoch 176/300
# 16/16 - 1s - loss: 0.5781 - accuracy: 0.7669 - val_loss: 0.6061 - val_accuracy: 0.7775 - 750ms/epoch - 47ms/step
# Epoch 177/300
# 16/16 - 1s - loss: 0.5719 - accuracy: 0.7669 - val_loss: 0.6030 - val_accuracy: 0.7713 - 803ms/epoch - 50ms/step
# Epoch 178/300
# 16/16 - 1s - loss: 0.5816 - accuracy: 0.7697 - val_loss: 0.5746 - val_accuracy: 0.7862 - 718ms/epoch - 45ms/step
# Epoch 179/300
# 16/16 - 1s - loss: 0.5929 - accuracy: 0.7631 - val_loss: 0.5802 - val_accuracy: 0.7875 - 683ms/epoch - 43ms/step
# Epoch 180/300
# 16/16 - 1s - loss: 0.5821 - accuracy: 0.7606 - val_loss: 0.5917 - val_accuracy: 0.7775 - 808ms/epoch - 50ms/step
# Epoch 181/300
# 16/16 - 1s - loss: 0.5720 - accuracy: 0.7731 - val_loss: 0.5805 - val_accuracy: 0.7788 - 715ms/epoch - 45ms/step
# Epoch 182/300
# 16/16 - 1s - loss: 0.5661 - accuracy: 0.7722 - val_loss: 0.5933 - val_accuracy: 0.7738 - 791ms/epoch - 49ms/step
# Epoch 183/300
# 16/16 - 1s - loss: 0.5732 - accuracy: 0.7675 - val_loss: 0.5755 - val_accuracy: 0.7937 - 723ms/epoch - 45ms/step
# Epoch 184/300
# 16/16 - 1s - loss: 0.5794 - accuracy: 0.7650 - val_loss: 0.5786 - val_accuracy: 0.7800 - 918ms/epoch - 57ms/step
# Epoch 185/300
# 16/16 - 1s - loss: 0.5667 - accuracy: 0.7747 - val_loss: 0.6393 - val_accuracy: 0.7588 - 941ms/epoch - 59ms/step
# Epoch 186/300
# 16/16 - 1s - loss: 0.5717 - accuracy: 0.7691 - val_loss: 0.6198 - val_accuracy: 0.7688 - 842ms/epoch - 53ms/step
# Epoch 187/300
# 16/16 - 1s - loss: 0.5718 - accuracy: 0.7656 - val_loss: 0.5807 - val_accuracy: 0.7887 - 862ms/epoch - 54ms/step
# Epoch 188/300
# 16/16 - 1s - loss: 0.5657 - accuracy: 0.7753 - val_loss: 0.6032 - val_accuracy: 0.7650 - 904ms/epoch - 56ms/step
# Epoch 189/300
# 16/16 - 1s - loss: 0.5740 - accuracy: 0.7694 - val_loss: 0.5892 - val_accuracy: 0.7837 - 862ms/epoch - 54ms/step
# Epoch 190/300
# 16/16 - 1s - loss: 0.5725 - accuracy: 0.7703 - val_loss: 0.6137 - val_accuracy: 0.7638 - 716ms/epoch - 45ms/step
# Epoch 191/300
# 16/16 - 1s - loss: 0.5634 - accuracy: 0.7703 - val_loss: 0.6001 - val_accuracy: 0.7700 - 741ms/epoch - 46ms/step
# Epoch 192/300
# 16/16 - 1s - loss: 0.5694 - accuracy: 0.7706 - val_loss: 0.5927 - val_accuracy: 0.7837 - 711ms/epoch - 44ms/step
# Epoch 193/300
# 16/16 - 1s - loss: 0.5688 - accuracy: 0.7703 - val_loss: 0.5837 - val_accuracy: 0.7750 - 814ms/epoch - 51ms/step
# Epoch 194/300
# 16/16 - 1s - loss: 0.5673 - accuracy: 0.7741 - val_loss: 0.6447 - val_accuracy: 0.7525 - 949ms/epoch - 59ms/step
# Epoch 195/300
# 16/16 - 1s - loss: 0.5901 - accuracy: 0.7628 - val_loss: 0.6369 - val_accuracy: 0.7675 - 1s/epoch - 65ms/step
# Epoch 196/300
# 16/16 - 1s - loss: 0.5689 - accuracy: 0.7691 - val_loss: 0.5823 - val_accuracy: 0.7775 - 935ms/epoch - 58ms/step
# Epoch 197/300
# 16/16 - 1s - loss: 0.5737 - accuracy: 0.7647 - val_loss: 0.6137 - val_accuracy: 0.7713 - 922ms/epoch - 58ms/step
# Epoch 198/300
# 16/16 - 1s - loss: 0.5651 - accuracy: 0.7681 - val_loss: 0.6213 - val_accuracy: 0.7675 - 792ms/epoch - 49ms/step
# Epoch 199/300
# 16/16 - 1s - loss: 0.5746 - accuracy: 0.7659 - val_loss: 0.6549 - val_accuracy: 0.7575 - 748ms/epoch - 47ms/step
# Epoch 200/300
# 16/16 - 1s - loss: 0.5551 - accuracy: 0.7709 - val_loss: 0.6314 - val_accuracy: 0.7650 - 796ms/epoch - 50ms/step
# Epoch 201/300
# 16/16 - 1s - loss: 0.5831 - accuracy: 0.7609 - val_loss: 0.6199 - val_accuracy: 0.7563 - 759ms/epoch - 47ms/step
# Epoch 202/300
# 16/16 - 1s - loss: 0.5598 - accuracy: 0.7731 - val_loss: 0.6599 - val_accuracy: 0.7550 - 720ms/epoch - 45ms/step
# Epoch 203/300
# 16/16 - 1s - loss: 0.5722 - accuracy: 0.7713 - val_loss: 0.5847 - val_accuracy: 0.7825 - 756ms/epoch - 47ms/step
# Epoch 204/300
# 16/16 - 1s - loss: 0.5594 - accuracy: 0.7750 - val_loss: 0.5876 - val_accuracy: 0.7763 - 885ms/epoch - 55ms/step
# Epoch 205/300
# 16/16 - 1s - loss: 0.5815 - accuracy: 0.7588 - val_loss: 0.5840 - val_accuracy: 0.7850 - 769ms/epoch - 48ms/step
# Epoch 206/300
# 16/16 - 1s - loss: 0.5565 - accuracy: 0.7741 - val_loss: 0.5879 - val_accuracy: 0.7900 - 917ms/epoch - 57ms/step
# Epoch 207/300
# 16/16 - 1s - loss: 0.5694 - accuracy: 0.7728 - val_loss: 0.6160 - val_accuracy: 0.7675 - 765ms/epoch - 48ms/step
# Epoch 208/300
# 16/16 - 1s - loss: 0.5575 - accuracy: 0.7722 - val_loss: 0.5987 - val_accuracy: 0.7738 - 838ms/epoch - 52ms/step
# Epoch 209/300
# 16/16 - 1s - loss: 0.6249 - accuracy: 0.7566 - val_loss: 0.6110 - val_accuracy: 0.7588 - 923ms/epoch - 58ms/step
# Epoch 210/300
# 16/16 - 1s - loss: 0.5607 - accuracy: 0.7750 - val_loss: 0.6515 - val_accuracy: 0.7588 - 940ms/epoch - 59ms/step
# Epoch 211/300
# 16/16 - 1s - loss: 0.5643 - accuracy: 0.7725 - val_loss: 0.5989 - val_accuracy: 0.7775 - 987ms/epoch - 62ms/step
# Epoch 212/300
# 16/16 - 1s - loss: 0.5597 - accuracy: 0.7675 - val_loss: 0.6292 - val_accuracy: 0.7738 - 925ms/epoch - 58ms/step
# Epoch 213/300
# 16/16 - 1s - loss: 0.5614 - accuracy: 0.7775 - val_loss: 0.6093 - val_accuracy: 0.7650 - 1s/epoch - 63ms/step
# Epoch 214/300
# 16/16 - 1s - loss: 0.5761 - accuracy: 0.7613 - val_loss: 0.5953 - val_accuracy: 0.7738 - 806ms/epoch - 50ms/step
# Epoch 215/300
# 16/16 - 1s - loss: 0.5507 - accuracy: 0.7850 - val_loss: 0.5860 - val_accuracy: 0.7763 - 896ms/epoch - 56ms/step
# Epoch 216/300
# 16/16 - 1s - loss: 0.5737 - accuracy: 0.7772 - val_loss: 0.5981 - val_accuracy: 0.7688 - 835ms/epoch - 52ms/step
# Epoch 217/300
# 16/16 - 1s - loss: 0.5680 - accuracy: 0.7684 - val_loss: 0.6184 - val_accuracy: 0.7613 - 761ms/epoch - 48ms/step
# Epoch 218/300
# 16/16 - 1s - loss: 0.5765 - accuracy: 0.7691 - val_loss: 0.6711 - val_accuracy: 0.7525 - 878ms/epoch - 55ms/step
# Epoch 219/300
# 16/16 - 1s - loss: 0.5811 - accuracy: 0.7681 - val_loss: 0.6044 - val_accuracy: 0.7688 - 830ms/epoch - 52ms/step
# Epoch 220/300
# 16/16 - 1s - loss: 0.5670 - accuracy: 0.7678 - val_loss: 0.6237 - val_accuracy: 0.7600 - 954ms/epoch - 60ms/step
# Epoch 221/300
# 16/16 - 1s - loss: 0.5784 - accuracy: 0.7672 - val_loss: 0.6009 - val_accuracy: 0.7788 - 840ms/epoch - 53ms/step
# Epoch 222/300
# 16/16 - 1s - loss: 0.5596 - accuracy: 0.7709 - val_loss: 0.6025 - val_accuracy: 0.7700 - 865ms/epoch - 54ms/step
# Epoch 223/300
# 16/16 - 1s - loss: 0.5698 - accuracy: 0.7741 - val_loss: 0.6001 - val_accuracy: 0.7738 - 848ms/epoch - 53ms/step
# Epoch 224/300
# 16/16 - 1s - loss: 0.5601 - accuracy: 0.7816 - val_loss: 0.5921 - val_accuracy: 0.7775 - 795ms/epoch - 50ms/step
# Epoch 225/300
# 16/16 - 1s - loss: 0.5552 - accuracy: 0.7778 - val_loss: 0.6184 - val_accuracy: 0.7738 - 907ms/epoch - 57ms/step
# Epoch 226/300
# 16/16 - 1s - loss: 0.5839 - accuracy: 0.7616 - val_loss: 0.6485 - val_accuracy: 0.7600 - 709ms/epoch - 44ms/step
# Epoch 227/300
# 16/16 - 1s - loss: 0.5584 - accuracy: 0.7809 - val_loss: 0.6122 - val_accuracy: 0.7675 - 728ms/epoch - 46ms/step
# Epoch 228/300
# 16/16 - 1s - loss: 0.5746 - accuracy: 0.7725 - val_loss: 0.6118 - val_accuracy: 0.7588 - 747ms/epoch - 47ms/step
# Epoch 229/300
# 16/16 - 1s - loss: 0.5574 - accuracy: 0.7734 - val_loss: 0.6304 - val_accuracy: 0.7513 - 914ms/epoch - 57ms/step
# Epoch 230/300
# 16/16 - 1s - loss: 0.5645 - accuracy: 0.7784 - val_loss: 0.5903 - val_accuracy: 0.7775 - 988ms/epoch - 62ms/step
# Epoch 231/300
# 16/16 - 1s - loss: 0.5658 - accuracy: 0.7775 - val_loss: 0.6507 - val_accuracy: 0.7625 - 960ms/epoch - 60ms/step
# Epoch 232/300
# 16/16 - 1s - loss: 0.5549 - accuracy: 0.7734 - val_loss: 0.6017 - val_accuracy: 0.7675 - 1s/epoch - 63ms/step
# Epoch 233/300
# 16/16 - 1s - loss: 0.5665 - accuracy: 0.7731 - val_loss: 0.6255 - val_accuracy: 0.7575 - 875ms/epoch - 55ms/step
# Epoch 234/300
# 16/16 - 1s - loss: 0.5544 - accuracy: 0.7784 - val_loss: 0.6054 - val_accuracy: 0.7563 - 885ms/epoch - 55ms/step
# Epoch 235/300
# 16/16 - 1s - loss: 0.5716 - accuracy: 0.7725 - val_loss: 0.6585 - val_accuracy: 0.7600 - 860ms/epoch - 54ms/step
# Epoch 236/300
# 16/16 - 1s - loss: 0.5644 - accuracy: 0.7706 - val_loss: 0.6164 - val_accuracy: 0.7750 - 1s/epoch - 68ms/step
# Epoch 237/300
# 16/16 - 1s - loss: 0.5633 - accuracy: 0.7703 - val_loss: 0.6019 - val_accuracy: 0.7763 - 877ms/epoch - 55ms/step
# Epoch 238/300
# 16/16 - 1s - loss: 0.5638 - accuracy: 0.7744 - val_loss: 0.6110 - val_accuracy: 0.7663 - 821ms/epoch - 51ms/step
# Epoch 239/300
# 16/16 - 1s - loss: 0.5526 - accuracy: 0.7759 - val_loss: 0.6164 - val_accuracy: 0.7763 - 780ms/epoch - 49ms/step
# Epoch 240/300
# 16/16 - 1s - loss: 0.5576 - accuracy: 0.7722 - val_loss: 0.6027 - val_accuracy: 0.7788 - 1s/epoch - 71ms/step
# Epoch 241/300
# 16/16 - 1s - loss: 0.5570 - accuracy: 0.7728 - val_loss: 0.6142 - val_accuracy: 0.7588 - 985ms/epoch - 62ms/step
# Epoch 242/300
# 16/16 - 1s - loss: 0.5860 - accuracy: 0.7656 - val_loss: 0.5832 - val_accuracy: 0.7713 - 840ms/epoch - 52ms/step
# Epoch 243/300
# 16/16 - 1s - loss: 0.5577 - accuracy: 0.7734 - val_loss: 0.6021 - val_accuracy: 0.7738 - 967ms/epoch - 60ms/step
# Epoch 244/300
# 16/16 - 1s - loss: 0.5633 - accuracy: 0.7772 - val_loss: 0.5933 - val_accuracy: 0.7788 - 1s/epoch - 73ms/step
# Epoch 245/300
# 16/16 - 1s - loss: 0.5660 - accuracy: 0.7734 - val_loss: 0.6334 - val_accuracy: 0.7500 - 806ms/epoch - 50ms/step
# Epoch 246/300
# 16/16 - 1s - loss: 0.5596 - accuracy: 0.7772 - val_loss: 0.6164 - val_accuracy: 0.7650 - 745ms/epoch - 47ms/step
# Epoch 247/300
# 16/16 - 1s - loss: 0.5698 - accuracy: 0.7716 - val_loss: 0.6308 - val_accuracy: 0.7675 - 809ms/epoch - 51ms/step
# Epoch 248/300
# 16/16 - 1s - loss: 0.5716 - accuracy: 0.7731 - val_loss: 0.6064 - val_accuracy: 0.7525 - 696ms/epoch - 44ms/step
# Epoch 249/300
# 16/16 - 1s - loss: 0.5693 - accuracy: 0.7738 - val_loss: 0.6100 - val_accuracy: 0.7725 - 756ms/epoch - 47ms/step
# Epoch 250/300
# 16/16 - 1s - loss: 0.5657 - accuracy: 0.7731 - val_loss: 0.6055 - val_accuracy: 0.7788 - 714ms/epoch - 45ms/step
# Epoch 251/300
# 16/16 - 1s - loss: 0.5757 - accuracy: 0.7731 - val_loss: 0.6416 - val_accuracy: 0.7650 - 779ms/epoch - 49ms/step
# Epoch 252/300
# 16/16 - 1s - loss: 0.5602 - accuracy: 0.7744 - val_loss: 0.6917 - val_accuracy: 0.7387 - 707ms/epoch - 44ms/step
# Epoch 253/300
# 16/16 - 1s - loss: 0.5616 - accuracy: 0.7816 - val_loss: 0.6099 - val_accuracy: 0.7675 - 672ms/epoch - 42ms/step
# Epoch 254/300
# 16/16 - 1s - loss: 0.5613 - accuracy: 0.7756 - val_loss: 0.5924 - val_accuracy: 0.7788 - 790ms/epoch - 49ms/step
# Epoch 255/300
# 16/16 - 1s - loss: 0.5717 - accuracy: 0.7703 - val_loss: 0.6074 - val_accuracy: 0.7650 - 914ms/epoch - 57ms/step
# Epoch 256/300
# 16/16 - 1s - loss: 0.5536 - accuracy: 0.7812 - val_loss: 0.6188 - val_accuracy: 0.7775 - 929ms/epoch - 58ms/step
# Epoch 257/300
# 16/16 - 1s - loss: 0.5594 - accuracy: 0.7812 - val_loss: 0.6539 - val_accuracy: 0.7575 - 965ms/epoch - 60ms/step
# Epoch 258/300
# 16/16 - 1s - loss: 0.5586 - accuracy: 0.7803 - val_loss: 0.6182 - val_accuracy: 0.7575 - 926ms/epoch - 58ms/step
# Epoch 259/300
# 16/16 - 1s - loss: 0.5610 - accuracy: 0.7763 - val_loss: 0.6068 - val_accuracy: 0.7638 - 1s/epoch - 65ms/step
# Epoch 260/300
# 16/16 - 1s - loss: 0.5567 - accuracy: 0.7819 - val_loss: 0.6176 - val_accuracy: 0.7688 - 930ms/epoch - 58ms/step
# Epoch 261/300
# 16/16 - 1s - loss: 0.5572 - accuracy: 0.7803 - val_loss: 0.6235 - val_accuracy: 0.7600 - 721ms/epoch - 45ms/step
# Epoch 262/300
# 16/16 - 1s - loss: 0.5503 - accuracy: 0.7841 - val_loss: 0.6385 - val_accuracy: 0.7625 - 797ms/epoch - 50ms/step
# Epoch 263/300
# 16/16 - 1s - loss: 0.5628 - accuracy: 0.7709 - val_loss: 0.6271 - val_accuracy: 0.7763 - 858ms/epoch - 54ms/step
# Epoch 264/300
# 16/16 - 1s - loss: 0.5551 - accuracy: 0.7744 - val_loss: 0.6077 - val_accuracy: 0.7713 - 1s/epoch - 72ms/step
# Epoch 265/300
# 16/16 - 1s - loss: 0.5629 - accuracy: 0.7788 - val_loss: 0.6386 - val_accuracy: 0.7475 - 945ms/epoch - 59ms/step
# Epoch 266/300
# 16/16 - 1s - loss: 0.5537 - accuracy: 0.7862 - val_loss: 0.6146 - val_accuracy: 0.7713 - 917ms/epoch - 57ms/step
# Epoch 267/300
# 16/16 - 1s - loss: 0.5446 - accuracy: 0.7875 - val_loss: 0.6246 - val_accuracy: 0.7788 - 958ms/epoch - 60ms/step
# Epoch 268/300
# 16/16 - 1s - loss: 0.5933 - accuracy: 0.7603 - val_loss: 0.6166 - val_accuracy: 0.7675 - 813ms/epoch - 51ms/step
# Epoch 269/300
# 16/16 - 1s - loss: 0.5573 - accuracy: 0.7750 - val_loss: 0.6765 - val_accuracy: 0.7500 - 927ms/epoch - 58ms/step
# Epoch 270/300
# 16/16 - 1s - loss: 0.5822 - accuracy: 0.7656 - val_loss: 0.6034 - val_accuracy: 0.7650 - 1s/epoch - 65ms/step
# Epoch 271/300
# 16/16 - 1s - loss: 0.5517 - accuracy: 0.7809 - val_loss: 0.6059 - val_accuracy: 0.7650 - 730ms/epoch - 46ms/step
# Epoch 272/300
# 16/16 - 1s - loss: 0.5351 - accuracy: 0.7869 - val_loss: 0.7256 - val_accuracy: 0.7400 - 696ms/epoch - 44ms/step
# Epoch 273/300
# 16/16 - 1s - loss: 0.5692 - accuracy: 0.7709 - val_loss: 0.6348 - val_accuracy: 0.7663 - 682ms/epoch - 43ms/step
# Epoch 274/300
# 16/16 - 1s - loss: 0.5463 - accuracy: 0.7875 - val_loss: 0.6337 - val_accuracy: 0.7475 - 713ms/epoch - 45ms/step
# Epoch 275/300
# 16/16 - 1s - loss: 0.5515 - accuracy: 0.7803 - val_loss: 0.6280 - val_accuracy: 0.7513 - 734ms/epoch - 46ms/step
# Epoch 276/300
# 16/16 - 1s - loss: 0.5773 - accuracy: 0.7666 - val_loss: 0.6549 - val_accuracy: 0.7638 - 697ms/epoch - 44ms/step
# Epoch 277/300
# 16/16 - 1s - loss: 0.5528 - accuracy: 0.7800 - val_loss: 0.6149 - val_accuracy: 0.7613 - 742ms/epoch - 46ms/step
# Epoch 278/300
# 16/16 - 1s - loss: 0.5731 - accuracy: 0.7706 - val_loss: 0.6294 - val_accuracy: 0.7638 - 945ms/epoch - 59ms/step
# Epoch 279/300
# 16/16 - 1s - loss: 0.5732 - accuracy: 0.7731 - val_loss: 0.6255 - val_accuracy: 0.7575 - 773ms/epoch - 48ms/step
# Epoch 280/300
# 16/16 - 1s - loss: 0.5520 - accuracy: 0.7784 - val_loss: 0.6788 - val_accuracy: 0.7563 - 1s/epoch - 68ms/step
# Epoch 281/300
# 16/16 - 1s - loss: 0.5414 - accuracy: 0.7850 - val_loss: 0.6336 - val_accuracy: 0.7563 - 976ms/epoch - 61ms/step
# Epoch 282/300
# 16/16 - 1s - loss: 0.5973 - accuracy: 0.7688 - val_loss: 0.5996 - val_accuracy: 0.7663 - 983ms/epoch - 61ms/step
# Epoch 283/300
# 16/16 - 1s - loss: 0.5547 - accuracy: 0.7756 - val_loss: 0.6301 - val_accuracy: 0.7563 - 856ms/epoch - 54ms/step
# Epoch 284/300
# 16/16 - 1s - loss: 0.5421 - accuracy: 0.7822 - val_loss: 0.6238 - val_accuracy: 0.7688 - 823ms/epoch - 51ms/step
# Epoch 285/300
# 16/16 - 1s - loss: 0.5579 - accuracy: 0.7750 - val_loss: 0.6115 - val_accuracy: 0.7775 - 826ms/epoch - 52ms/step
# Epoch 286/300
# 16/16 - 1s - loss: 0.5534 - accuracy: 0.7841 - val_loss: 0.6011 - val_accuracy: 0.7812 - 826ms/epoch - 52ms/step
# Epoch 287/300
# 16/16 - 1s - loss: 0.5687 - accuracy: 0.7728 - val_loss: 0.6212 - val_accuracy: 0.7663 - 793ms/epoch - 50ms/step
# Epoch 288/300
# 16/16 - 1s - loss: 0.5591 - accuracy: 0.7781 - val_loss: 0.6318 - val_accuracy: 0.7625 - 890ms/epoch - 56ms/step
# Epoch 289/300
# 16/16 - 1s - loss: 0.5660 - accuracy: 0.7756 - val_loss: 0.6085 - val_accuracy: 0.7688 - 664ms/epoch - 42ms/step
# Epoch 290/300
# 16/16 - 1s - loss: 0.5496 - accuracy: 0.7800 - val_loss: 0.6596 - val_accuracy: 0.7525 - 764ms/epoch - 48ms/step
# Epoch 291/300
# 16/16 - 1s - loss: 0.5467 - accuracy: 0.7878 - val_loss: 0.6284 - val_accuracy: 0.7675 - 795ms/epoch - 50ms/step
# Epoch 292/300
# 16/16 - 1s - loss: 0.5455 - accuracy: 0.7809 - val_loss: 0.6803 - val_accuracy: 0.7563 - 977ms/epoch - 61ms/step
# Epoch 293/300
# 16/16 - 1s - loss: 0.5567 - accuracy: 0.7772 - val_loss: 0.6322 - val_accuracy: 0.7525 - 967ms/epoch - 60ms/step
# Epoch 294/300
# 16/16 - 1s - loss: 0.5440 - accuracy: 0.7866 - val_loss: 0.6450 - val_accuracy: 0.7638 - 987ms/epoch - 62ms/step
# Epoch 295/300
# 16/16 - 1s - loss: 0.5491 - accuracy: 0.7862 - val_loss: 0.6123 - val_accuracy: 0.7700 - 772ms/epoch - 48ms/step
# Epoch 296/300
# 16/16 - 1s - loss: 0.5519 - accuracy: 0.7806 - val_loss: 0.6102 - val_accuracy: 0.7775 - 725ms/epoch - 45ms/step
# Epoch 297/300
# 16/16 - 1s - loss: 0.5585 - accuracy: 0.7756 - val_loss: 0.6091 - val_accuracy: 0.7763 - 732ms/epoch - 46ms/step
# Epoch 298/300
# 16/16 - 1s - loss: 0.5559 - accuracy: 0.7781 - val_loss: 0.6260 - val_accuracy: 0.7563 - 787ms/epoch - 49ms/step
# Epoch 299/300
# 16/16 - 1s - loss: 0.5712 - accuracy: 0.7750 - val_loss: 0.6239 - val_accuracy: 0.7563 - 862ms/epoch - 54ms/step
# Epoch 300/300
# 16/16 - 1s - loss: 0.5635 - accuracy: 0.7769 - val_loss: 0.6093 - val_accuracy: 0.7800 - 686ms/epoch - 43ms/step
# end of fit

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)

# %%
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["Class 0","Class 1","Class 2"]

def show_confusion_matrix(validations, predictions, label="Model",perc=False):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    M = matrix
    f = 'd'
    cmap="GnBu"
    if perc:
        M=M/np.sum(M)
        f='.2%'
        cmap='Blues'
    seaborn.heatmap(M,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt=f,
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = np.array(model.predict(x_val))
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val,perc=True)

# %%
model2 = keras.models.clone_model(model)

reg2 = keras.regularizers.l2(0.5)
model2.layers[0].kernel_regularizer = reg2
model2.layers[1].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2

opt = tf.keras.optimizers.legacy.Adam()
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])

BATCH_SIZE2 = 200
EPOCHS2 = 300

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)

# %%
Show_history(fit)
Show_history(fit2)

Show_weights(model,0,label="model1")
Show_weights(model2,0,label="model2")
Show_weights(model,2,label="model1")
Show_weights(model2,2,label="model2")


y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val, label="Model 1")
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")
